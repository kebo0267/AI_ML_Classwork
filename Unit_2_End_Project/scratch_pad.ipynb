# %%
import base64
import json
from datetime import datetime, timedelta
import pandas as pd
from pandas.api.types import is_datetime64_any_dtype

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = ["a","x",1]
b = ["b","",2]
c = ["c","z",]
d = []
columns = ["A","B","C"]

d.append(a)
d.append(b)
d.append(c)

df = pd.DataFrame(d,columns=columns)




print(df)
# Out:
#    A  B    C
# 0  a  x  1.0
# 1  b     2.0
# 2  c  z  NaN

# %%
col = "C"
null_indexes = set()
print(df[df[col].isnull()].index)
null_indexes.update(df[df[col].isna()].index.tolist())
null_indexes.update(df[df[col].isnull()].index.tolist())
print(null_indexes)
# Out:
# Index([2], dtype='int64')
# {2}

# %%
s = pd.Series(['2023-01-15_data', '15-01-2023_report', 'invalid_string', '2023-99-99_error'])

# Extract the potential date part (e.g., first 10 characters for YYYY-MM-DD)
potential_dates = s.str[:10]

# Attempt conversion, coercing errors to NaT
converted_dates = pd.to_datetime(potential_dates, errors='coerce')

# Check if the conversion was successful (not NaT)
is_valid_datetime_start = converted_dates.notna()
print(converted_dates)
print(is_valid_datetime_start)
# Out:
# 0   2023-01-15
# 1          NaT
# 2          NaT
# 3          NaT
# dtype: datetime64[ns]
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
test = ["hello","goodbye"]
"hello" in test
# Out:
# True
